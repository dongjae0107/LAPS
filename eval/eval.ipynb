# %%
from pathlib import Path
from eval_utils import run_eval_mesh

ROOT = Path.cwd().parent

# Mai City Dataset
pred_mesh_path = ROOT / "output/maicity/maicity_xxx/mesh.ply"
gt_pcd_path = ROOT / "dataset/maicity/mai_city/gt_map_pc_mai.ply" # https://github.com/PRBonn/SHINE_mapping/blob/master/eval/evaluator.py

# Parameters
downsample_size = 0.02
threshold = 0.1
truncation_precision = 0.2
truncation_recall = 2.0

# Run eval
run_eval_mesh(
    pred_mesh_path=pred_mesh_path,
    gt_pcd_path=gt_pcd_path,
    downsample_size=downsample_size,
    threshold=threshold,
    truncation_precision=truncation_precision,
    truncation_recall=truncation_recall
)

# %%
from pathlib import Path
from eval_utils import run_eval_mesh

ROOT = Path.cwd().parent

# Newer College Dataset
pred_mesh_path = ROOT / "output/ncd/ncd_xxx/mesh.ply"
gt_pcd_path = ROOT / "dataset/ncd/newer_college/ncd_quad_gt_pc.ply"

# Parameters
downsample_size = 0.02
threshold = 0.2
truncation_precision = 0.4
truncation_recall = 2.0

# Run eval
run_eval_mesh(
    pred_mesh_path=pred_mesh_path,
    gt_pcd_path=gt_pcd_path,
    downsample_size=downsample_size,
    threshold=threshold,
    truncation_precision=truncation_precision,
    truncation_recall=truncation_recall
)

# %%
from pathlib import Path
from eval_utils import run_eval_mesh

ROOT = Path.cwd().parent

# Newer College Dataset
pred_mesh_path = ROOT / "output/spires/observatory_quarter_01/spires_xxx/mesh.ply"

# Blenheim Palace 05
gt_pcd_path = ROOT / "dataset/spires/Oxford-Spires/blenheim_palace_05/gt_cloud_merged.pcd"

# Christ Church 02
# gt_pcd_path = ROOT / "dataset/spires/Oxford-Spires/christ_church_02/gt_cloud_merged.pcd"

# Keble College 04
# gt_pcd_path = ROOT / "dataset/spires/Oxford-Spires/keble_college_04/gt_cloud_merged.pcd"

# Observatory Quarter 01
# gt_pcd_path = ROOT / "dataset/spires/Oxford-Spires/observatory_quarter_01/gt_cloud_merged.pcd"

# Parameters
downsample_size = 0.02
threshold = 0.2
truncation_precision = 0.4
truncation_recall = 2.0

# Run eval
run_eval_mesh(
    pred_mesh_path=pred_mesh_path,
    gt_pcd_path=gt_pcd_path,
    downsample_size=downsample_size,
    threshold=threshold,
    truncation_precision=truncation_precision,
    truncation_recall=truncation_recall
)
